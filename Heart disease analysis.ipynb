# %%
# Install libraries

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import libraries and load dataset

# %%
import pandas as pd

# %%
df=pd.read_excel("C:/Users/vamsi/Downloads/Heart disease project/heart_dataset_practice.xlsx")

# %%
df.head()
# Out:
#    age     Sex                cp  trestbps  chol     fbs  restecg  thalach  \
# 0   63    Male      Asymptomatic       145   233    High   Normal      150
# 1   37    Male  Non anginal pain       130   250  Normal  Warning      187
# 2   41  Female   Atypical angina       130   204  Normal   Normal      172
# 3   56    Male   Atypical angina       120   236  Normal  Warning      178
# 4   57  Female    Typical angina       120   354  Normal  Warning      163
#
#   exang  oldpeak  slope  ca               thal             target  BP_level  \
# 0    No      2.3      0   0             Normal  Has heart disease      High
# 1    No      3.5      0   0  Permanent Problem  Has heart disease  Elevated
# 2    No      1.4      2   0  Permanent Problem  Has heart disease  Elevated
# 3    No      0.8      2   0  Permanent Problem  Has heart disease  Elevated
# 4   Yes      0.6      2   0  Permanent Problem  Has heart disease  Elevated
#
# ...

# %%
# Understand dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              303 non-null    int64
#  1   Sex              303 non-null    object
#  2   cp               303 non-null    object
#  3   trestbps         303 non-null    int64
#  4   chol             303 non-null    int64
#  5   fbs              303 non-null    object
#  6   restecg          303 non-null    object
#  7   thalach          303 non-null    int64
#  8   exang            303 non-null    object
#  9   oldpeak          303 non-null    float64
#  10  slope            303 non-null    int64
#  11  ca               303 non-null    int64
#  12  thal             303 non-null    object
#  13  target           303 non-null    object
#  14  BP_level         303 non-null    object
#  15  chol_level       303 non-null    object
#  16  Heartrate_level  303 non-null    object
# ...

# %%
df.shape
# Out:
# (303, 20)

# %%
df.dtypes
# Out:
# age                  int64
# Sex                 object
# cp                  object
# trestbps             int64
# chol                 int64
# fbs                 object
# restecg             object
# thalach              int64
# exang               object
# oldpeak            float64
# slope                int64
# ca                   int64
# thal                object
# target              object
# BP_level            object
# chol_level          object
# Heartrate_level     object
# Stress_level        object
# Slope_level         object
# vessel_blockage     object
# dtype: object

# %%
# Statistics summary

# %%
df.describe()
# Out:
#               age    trestbps        chol     thalach     oldpeak       slope  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337  131.623762  246.264026  149.646865    1.039604    1.399340
# std      9.082101   17.538143   51.830751   22.905161    1.161075    0.616226
# min     29.000000   94.000000  126.000000   71.000000    0.000000    0.000000
# 25%     47.500000  120.000000  211.000000  133.500000    0.000000    1.000000
# 50%     55.000000  130.000000  240.000000  153.000000    0.800000    1.000000
# 75%     61.000000  140.000000  274.500000  166.000000    1.600000    2.000000
# max     77.000000  200.000000  564.000000  202.000000    6.200000    2.000000
#
#                ca
# count  303.000000
# mean     0.729373
# std      1.022606
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      4.000000

# %%
# check null values

# %%
df.isnull().sum()
# Out:
# age                0
# Sex                0
# cp                 0
# trestbps           0
# chol               0
# fbs                0
# restecg            0
# thalach            0
# exang              0
# oldpeak            0
# slope              0
# ca                 0
# thal               0
# target             0
# BP_level           0
# chol_level         0
# Heartrate_level    0
# Stress_level       0
# Slope_level        0
# vessel_blockage    0
# dtype: int64

# %%
# Note:- There is no null values in data

# %%
# check duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#      age   Sex                cp  trestbps  chol     fbs  restecg  thalach  \
# 164   38  Male  Non anginal pain       138   175  Normal  Warning      173
#
#     exang  oldpeak  slope  ca               thal             target  BP_level  \
# 164    No      0.0      2   4  Permanent Problem  Has heart disease  Elevated
#
#     chol_level Heartrate_level Stress_level Slope_level vessel_blockage
# 164     Normal            Good          Low   High Risk          Severe

# %%
df[df.duplicated(keep=False)]
# Out:
#      age   Sex                cp  trestbps  chol     fbs  restecg  thalach  \
# 163   38  Male  Non anginal pain       138   175  Normal  Warning      173
# 164   38  Male  Non anginal pain       138   175  Normal  Warning      173
#
#     exang  oldpeak  slope  ca               thal             target  BP_level  \
# 163    No      0.0      2   4  Permanent Problem  Has heart disease  Elevated
# 164    No      0.0      2   4  Permanent Problem  Has heart disease  Elevated
#
#     chol_level Heartrate_level Stress_level Slope_level vessel_blockage
# 163     Normal            Good          Low   High Risk          Severe
# 164     Normal            Good          Low   High Risk          Severe

# %%
# Remove duplicates

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Reset index

# %%
df=df.reset_index()

# %%
# Change column names clearly

# %%
df=df.rename(columns={
'cp':'chest_pain_type',
'trestbps':'blood_pressure_while_resting',
'chol':'cholesterol_in_blood',
'fbs':'blood_sugar_while_fasting',
'restecg':'ECG_while_resting',
'thalach':'heart_rate_during_excercise',
'exang':'chest_pain_during_excercise',
'oldpeak':'heart_stress_during_excercise',
'slope':'heart_stress_during_peak_excercise',
'ca':'blood_vessels',
'thal':'blood_flow_in_heart',
'target':'heart_disease_patient'})

# %%
df.head()
# Out:
#    index  age     Sex   chest_pain_type  blood_pressure_while_resting  \
# 0      0   63    Male      Asymptomatic                           145
# 1      1   37    Male  Non anginal pain                           130
# 2      2   41  Female   Atypical angina                           130
# 3      3   56    Male   Atypical angina                           120
# 4      4   57  Female    Typical angina                           120
#
#    cholesterol_in_blood blood_sugar_while_fasting ECG_while_resting  \
# 0                   233                      High            Normal
# 1                   250                    Normal           Warning
# 2                   204                    Normal            Normal
# 3                   236                    Normal           Warning
# 4                   354                    Normal           Warning
#
#    heart_rate_during_excercise chest_pain_during_excercise  ...  \
# 0                          150                          No  ...
# ...

# %%
# EDA - exploratory data analysis

# %%
# Check unique values

# %%
df['Sex'].value_counts()
df['chest_pain_type'].value_counts()
# Out:
# chest_pain_type
# Typical angina      143
# Non anginal pain     86
# Atypical angina      50
# Asymptomatic         23
# Name: count, dtype: int64

# %%
# Filtering rows

# %%
df[df['age'] > 50]
df[df['cholesterol_in_blood'] > 200]
# Out:
#      index  age     Sex   chest_pain_type  blood_pressure_while_resting  \
# 0        0   63    Male      Asymptomatic                           145
# 1        1   37    Male  Non anginal pain                           130
# 2        2   41  Female   Atypical angina                           130
# 3        3   56    Male   Atypical angina                           120
# 4        4   57  Female    Typical angina                           120
# ..     ...  ...     ...               ...                           ...
# 291    292   58  Female    Typical angina                           170
# 292    293   67    Male  Non anginal pain                           152
# 297    298   57  Female    Typical angina                           140
# 298    299   45    Male      Asymptomatic                           110
# 301    302   57  Female   Atypical angina                           130
#
#      cholesterol_in_blood blood_sugar_while_fasting ECG_while_resting  \
# ...

# %%
df.groupby('heart_disease_patient')['Sex'].count()
# Out:
# heart_disease_patient
# Has heart disease    164
# No heart disease     138
# Name: Sex, dtype: int64

# %%
df.groupby('Sex')['cholesterol_in_blood'].count()
# Out:
# Sex
# Female     96
# Male      206
# Name: cholesterol_in_blood, dtype: int64

# %%
# Save cleaned data

# %%
df.to_excel("C:/Users/vamsi/Downloads/Heart disease project/heart_dataset_practice.xlsx",index=False)
